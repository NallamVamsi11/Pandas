# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv")
#pd.read_csv("C:\\Users\\91868\\Data Science\\python\\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\\3Drepository.csv")
#pd.read_csv("C:/Users/91868/Data Science/python/WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)/3Drepository.csv")
# Out:
#                         repo_name         user_name  \
# 0                        three.js            mrdoob
# 1                          libgdx            libgdx
# 2               react-three-fiber            pmndrs
# 3                      Babylon.js         BabylonJS
# 4                          aframe          aframevr
# 5                    tinyrenderer             ssloy
# 6   3d-game-shaders-for-beginners           lettier
# 7                         FreeCAD           FreeCAD
# 8                            zdog         metafizzy
# 9                          cesium          CesiumGS
# 10            3D-Machine-Learning       timzhang642
# 11             SpaceshipGenerator      a1studmuffin
# 12                         Open3D           isl-org
# 13                       spritejs          spritejs
# 14                    tensorspace  tensorspace-team
# 15                 webglstudio.js           jagenjo
# 16                          PRNet           YadiraF
# ...

# %%
df=pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv")

# %%
df
# Out:
#                         repo_name         user_name  \
# 0                        three.js            mrdoob
# 1                          libgdx            libgdx
# 2               react-three-fiber            pmndrs
# 3                      Babylon.js         BabylonJS
# 4                          aframe          aframevr
# 5                    tinyrenderer             ssloy
# 6   3d-game-shaders-for-beginners           lettier
# 7                         FreeCAD           FreeCAD
# 8                            zdog         metafizzy
# 9                          cesium          CesiumGS
# 10            3D-Machine-Learning       timzhang642
# 11             SpaceshipGenerator      a1studmuffin
# 12                         Open3D           isl-org
# 13                       spritejs          spritejs
# 14                    tensorspace  tensorspace-team
# 15                 webglstudio.js           jagenjo
# 16                          PRNet           YadiraF
# ...

# %%
df.head(7)
# Out:
#                        repo_name  user_name  \
# 0                       three.js     mrdoob
# 1                         libgdx     libgdx
# 2              react-three-fiber     pmndrs
# 3                     Babylon.js  BabylonJS
# 4                         aframe   aframevr
# 5                   tinyrenderer      ssloy
# 6  3d-game-shaders-for-beginners    lettier
#
#                                             repo_url  no_stars
# 0                 https://github.com/mrdoob/three.js     74700
# 1                   https://github.com/libgdx/libgdx     19000
# 2        https://github.com/pmndrs/react-three-fiber     15200
# 3            https://github.com/BabylonJS/Babylon.js     15000
# 4                 https://github.com/aframevr/aframe     13100
# 5              https://github.com/ssloy/tinyrenderer     11300
# 6  https://github.com/lettier/3d-game-shaders-for...     11200

# %%
df.tail()
# Out:
#                   repo_name       user_name  \
# 25                    3DDFA       cleardusk
# 26  isometric-contributions       jasonlong
# 27                     rg3d      rg3dengine
# 28                  meshlab  cnr-isti-vclab
# 29                       L7          antvis
#
#                                              repo_url  no_stars
# 25                 https://github.com/cleardusk/3DDFA      3100
# 26  https://github.com/jasonlong/isometric-contrib...      3000
# 27                 https://github.com/rg3dengine/rg3d      2800
# 28          https://github.com/cnr-isti-vclab/meshlab      2400
# 29                       https://github.com/antvis/L7      2400

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
f5=df.head()

# %%
type(f5)
# Out:
# pandas.core.frame.DataFrame

# %%
f5.to_csv('test.csv')

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 5224-8246
#
#  Directory of C:\Users\91868\Data Science
#
# 28-02-2023  09:24    <DIR>          .
# 19-01-2023  17:43    <DIR>          ..
# 28-02-2023  08:37    <DIR>          .ipynb_checkpoints
# 28-02-2023  09:23            36,596 PANDAS.ipynb
# 08-01-2023  11:03    <DIR>          python
# 03-01-2023  10:55             6,115 sqlite.ipynb
# 28-02-2023  09:24               364 test.csv
#                3 File(s)         43,075 bytes
#                4 Dir(s)  264,149,708,800 bytes free

# %%
newdf=pd.read_csv('test.csv')

# %%
newdf
# Out:
#    Unnamed: 0          repo_name  user_name  \
# 0           0           three.js     mrdoob
# 1           1             libgdx     libgdx
# 2           2  react-three-fiber     pmndrs
# 3           3         Babylon.js  BabylonJS
# 4           4             aframe   aframevr
#
#                                       repo_url  no_stars
# 0           https://github.com/mrdoob/three.js     74700
# 1             https://github.com/libgdx/libgdx     19000
# 2  https://github.com/pmndrs/react-three-fiber     15200
# 3      https://github.com/BabylonJS/Babylon.js     15000
# 4           https://github.com/aframevr/aframe     13100

# %%
pd.read_csv('test.csv')
# Out:
#               #repo_name#user_name#repo_url#no_stars
# 0  0#three.js#mrdoob#https://github.com/mrdoob/th...
# 1  1#libgdx#libgdx#https://github.com/libgdx/libg...
# 2  2#react-three-fiber#pmndrs#https://github.com/...
# 3  3#Babylon.js#BabylonJS#https://github.com/Baby...
# 4  4#aframe#aframevr#https://github.com/aframevr/...

# %%
pd.read_csv('test.csv',sep='#')
# Out:
#    Unnamed: 0          repo_name  user_name  \
# 0           0           three.js     mrdoob
# 1           1             libgdx     libgdx
# 2           2  react-three-fiber     pmndrs
# 3           3         Babylon.js  BabylonJS
# 4           4             aframe   aframevr
#
#                                       repo_url  no_stars
# 0           https://github.com/mrdoob/three.js     74700
# 1             https://github.com/libgdx/libgdx     19000
# 2  https://github.com/pmndrs/react-three-fiber     15200
# 3      https://github.com/BabylonJS/Babylon.js     15000
# 4           https://github.com/aframevr/aframe     13100

# %%
pd.read_csv('test.csv',sep='#',header=None)
# Out:
#      0                  1          2  \
# 0  NaN          repo_name  user_name
# 1  0.0           three.js     mrdoob
# 2  1.0             libgdx     libgdx
# 3  2.0  react-three-fiber     pmndrs
# 4  3.0         Babylon.js  BabylonJS
# 5  4.0             aframe   aframevr
#
#                                              3         4
# 0                                     repo_url  no_stars
# 1           https://github.com/mrdoob/three.js     74700
# 2             https://github.com/libgdx/libgdx     19000
# 3  https://github.com/pmndrs/react-three-fiber     15200
# 4      https://github.com/BabylonJS/Babylon.js     15000
# 5           https://github.com/aframevr/aframe     13100

# %%
pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv",header=None)
# Out:
#                                 0                 1  \
# 0                       repo_name         user_name
# 1                        three.js            mrdoob
# 2                          libgdx            libgdx
# 3               react-three-fiber            pmndrs
# 4                      Babylon.js         BabylonJS
# 5                          aframe          aframevr
# 6                    tinyrenderer             ssloy
# 7   3d-game-shaders-for-beginners           lettier
# 8                         FreeCAD           FreeCAD
# 9                            zdog         metafizzy
# 10                         cesium          CesiumGS
# 11            3D-Machine-Learning       timzhang642
# 12             SpaceshipGenerator      a1studmuffin
# 13                         Open3D           isl-org
# 14                       spritejs          spritejs
# 15                    tensorspace  tensorspace-team
# 16                 webglstudio.js           jagenjo
# ...

# %%
pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv",header=None,
            names=['a','b','c','d'])
# Out:
#                                 a                 b  \
# 0                       repo_name         user_name
# 1                        three.js            mrdoob
# 2                          libgdx            libgdx
# 3               react-three-fiber            pmndrs
# 4                      Babylon.js         BabylonJS
# 5                          aframe          aframevr
# 6                    tinyrenderer             ssloy
# 7   3d-game-shaders-for-beginners           lettier
# 8                         FreeCAD           FreeCAD
# 9                            zdog         metafizzy
# 10                         cesium          CesiumGS
# 11            3D-Machine-Learning       timzhang642
# 12             SpaceshipGenerator      a1studmuffin
# 13                         Open3D           isl-org
# 14                       spritejs          spritejs
# 15                    tensorspace  tensorspace-team
# 16                 webglstudio.js           jagenjo
# ...

# %%
pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv",header=None,skiprows=[0,2,4])
# Out:
#                                 0                 1  \
# 0                        three.js            mrdoob
# 1               react-three-fiber            pmndrs
# 2                          aframe          aframevr
# 3                    tinyrenderer             ssloy
# 4   3d-game-shaders-for-beginners           lettier
# 5                         FreeCAD           FreeCAD
# 6                            zdog         metafizzy
# 7                          cesium          CesiumGS
# 8             3D-Machine-Learning       timzhang642
# 9              SpaceshipGenerator      a1studmuffin
# 10                         Open3D           isl-org
# 11                       spritejs          spritejs
# 12                    tensorspace  tensorspace-team
# 13                 webglstudio.js           jagenjo
# 14                          PRNet           YadiraF
# 15                            vrn      AaronJackson
# 16                     BlenderGIS           domlysz
# ...

# %%
pd.read_csv(r"C:\Users\91868\Data Science\python\WEB-SCRAPPING-MINI-PROJECT(GitHub-Topics)\3Drepository.csv",header=None,na_values=['aframe','zdog'])
# Out:
#                                 0                 1  \
# 0                       repo_name         user_name
# 1                        three.js            mrdoob
# 2                          libgdx            libgdx
# 3               react-three-fiber            pmndrs
# 4                      Babylon.js         BabylonJS
# 5                             NaN          aframevr
# 6                    tinyrenderer             ssloy
# 7   3d-game-shaders-for-beginners           lettier
# 8                         FreeCAD           FreeCAD
# 9                             NaN         metafizzy
# 10                         cesium          CesiumGS
# 11            3D-Machine-Learning       timzhang642
# 12             SpaceshipGenerator      a1studmuffin
# 13                         Open3D           isl-org
# 14                       spritejs          spritejs
# 15                    tensorspace  tensorspace-team
# 16                 webglstudio.js           jagenjo
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('uk-500.csv')

# %%
pd.read_csv('uk-500.csv',header=0,index_col=None,skiprows=[0,1,3,5],na_values=['Zigomalas','Rampy']).head()
# Out:
#       Evan  Zigomalas             Cap Gemini America           5 Binney St  \
# 0  Ulysses  Mcwalters                 Mcmahan, Ben L         505 Exeter Rd
# 1     Eric        NaN        Thompson, Michael C Esq          9472 Lind St
# 2     Marg   Grasmick  Wrangle Hill Auto Auct & Slvg      7457 Cowl St #70
# 3  Laquita      Hisaw          In Communications Inc  20 Gloucester Pl #96
# 4     Lura   Manzella                Bizerba Usa Inc      929 Augustine St
#
#            Abbey Ward        Buckinghamshire  HP11 2AX  01937-864715  \
# 0  Hawerby cum Beesby           Lincolnshire  DN36 5RP  01912-771311
# 1          Desborough       Northamptonshire  NN14 2GH  01969-886290
# 2        Bargate Ward            Southampton  SO14 3TY  01865-582516
# 3        Chirton Ward            Tyne & Wear  NE29 7AD  01746-394243
# 4    Staple Hill Ward  South Gloucestershire  BS16 4LL  01907-538509
#
#    01714-737668 evan.zigomalas@gmail.com  \
# 0  01302-601380      ulysses@hotmail.com
# ...

# %%
df
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
df.describe()
# Out:
#        first_name last_name      company_name       address  \
# count         500       500               500           500
# unique        479       498               498           500
# top       Antonio     Rampy  Martin Morrissey  14 Taylor St
# freq            3         2                 2             1
#
#                          city          county   postal        phone1  \
# count                     500             500      500           500
# unique                    468             102      500           500
# top     City and Hunslet Ward  Greater London  CT2 7PP  01835-703597
# freq                        3              44        1             1
#
#               phone2                    email  \
# count            500                      500
# unique           500                      500
# top     01944-369967  atomkiewicz@hotmail.com
# freq               1                        1
#
#                                      web
# ...

# %%
df.dtypes
# Out:
# first_name      object
# last_name       object
# company_name    object
# address         object
# city            object
# county          object
# postal          object
# phone1          object
# phone2          object
# email           object
# web             object
# dtype: object

# %%
df1=pd.read_csv(r"C:\Users\91868\Downloads\data1.csv")

# %%
df1
# Out:
#    capacity  score  length
# 0         1     10      30
# 1         2     20      30
# 2         3     30      40
# 3         3     40      30
# 4         2     30      40
# 5         7     10      23
# 6         3     20      22
# 7         8     20      11
# 8         2     30       2

# %%
df1.describe()
# Out:
#        capacity      score     length
# count  9.000000   9.000000   9.000000
# mean   3.444444  23.333333  25.333333
# std    2.403701  10.000000  12.559857
# min    1.000000  10.000000   2.000000
# 25%    2.000000  20.000000  22.000000
# 50%    3.000000  20.000000  30.000000
# 75%    3.000000  30.000000  30.000000
# max    8.000000  40.000000  40.000000

# %%
df1.dtypes
# Out:
# capacity    int64
# score       int64
# length      int64
# dtype: object

# %%
df.describe(percentiles=[.5,.6],include='all')
# Out:
#        first_name last_name      company_name       address  \
# count         500       500               500           500
# unique        479       498               498           500
# top       Antonio     Rampy  Martin Morrissey  14 Taylor St
# freq            3         2                 2             1
#
#                          city          county   postal        phone1  \
# count                     500             500      500           500
# unique                    468             102      500           500
# top     City and Hunslet Ward  Greater London  CT2 7PP  01835-703597
# freq                        3              44        1             1
#
#               phone2                    email  \
# count            500                      500
# unique           500                      500
# top     01944-369967  atomkiewicz@hotmail.com
# freq               1                        1
#
#                                      web
# ...

# %%
 df = pd.DataFrame({'categorical': pd.Categorical(['d','e','f']),
                    'numeric': [1, 2, 3],
                    'object': ['a', 'b', 'c']
                   })

# %%
df
# Out:
#   categorical  numeric object
# 0           d        1      a
# 1           e        2      b
# 2           f        3      c

# %%
df.describe(percentiles=[.5],include='all')
# Out:
#        categorical  numeric object
# count            3      3.0      3
# unique           3      NaN      3
# top              d      NaN      a
# freq             1      NaN      1
# mean           NaN      2.0    NaN
# std            NaN      1.0    NaN
# min            NaN      1.0    NaN
# 50%            NaN      2.0    NaN
# max            NaN      3.0    NaN

# %%
df.describe(percentiles=[0.5],include=[object,'category'])
# Out:
#        categorical object
# count            3      3
# unique           3      3
# top              d      a
# freq             1      1

# %%
import pandas as pd
df=pd.read_csv('uk-500.csv')

# %%
df
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
df.to_csv('uk500.csv',index=False,header=None)

# %%
df.to_csv('uk501.csv',index=False,header=None,sep='&')

# %%
df.to_csv('uk502.csv',index=False,header=None,sep='&',columns=['first_name','last_name','postal'])

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web'],
#       dtype='object')

# %%
type(df['phone1'])
# Out:
# pandas.core.series.Series

# %%
df[['phone1']]
# Out:
#            phone1
# 0    01835-703597
# 1    01937-864715
# 2    01347-368222
# 3    01912-771311
# 4    01547-429341
# ..            ...
# 495  01748-625058
# 496  01916-963261
# 497  01888-152110
# 498  01877-379681
# 499  01451-785624
#
# [500 rows x 1 columns]

# %%
type(df[['phone1']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['city','county']]
# Out:
#                                city           county
# 0                 St. Stephens Ward             Kent
# 1                        Abbey Ward  Buckinghamshire
# 2    East Southbourne and Tuckton W      Bournemouth
# 3                Hawerby cum Beesby     Lincolnshire
# 4        Greets Green and Lyng Ward    West Midlands
# ..                              ...              ...
# 495  Knightsbridge and Belgravia Wa   Greater London
# 496        Inverness Ness-Side Ward         Highland
# 497                Darton West Ward  South Yorkshire
# 498                Consett North ED    County Durham
# 499               Tanworth-in-Arden     Warwickshire
#
# [500 rows x 2 columns]

# %%
df[list(df.columns)[0:6:2]]
# Out:
#     first_name                    company_name                            city
# 0      Aleshia         Alan D Rosenburg Cpa Pc               St. Stephens Ward
# 1         Evan              Cap Gemini America                      Abbey Ward
# 2       France             Elliott, John W Esq  East Southbourne and Tuckton W
# 3      Ulysses                  Mcmahan, Ben L              Hawerby cum Beesby
# 4       Tyisha                  Champagne Room      Greets Green and Lyng Ward
# ..         ...                             ...                             ...
# 495      Avery      Plaza Gourmet Delicatessen  Knightsbridge and Belgravia Wa
# 496       Reid            Fitzgerald, Edward J        Inverness Ness-Side Ward
# 497  Charlette              Furey & Associates                Darton West Ward
# 498  Celestina        Bfg Federal Credit Union                Consett North ED
# 499         Mi  Nelson Wright Haworth Golf Crs               Tanworth-in-Arden
#
# [500 rows x 3 columns]

# %%
dfh=pd.read_html('https://www.espncricinfo.com/cricketers/kane-williamson-277906/bowling-batting-stats')

# %%
dfh
# Out:
# [  Unnamed: 0       Span  Mat  Inns  NO  Runs   HS    Avg     BF     SR  100s  \
#  0   overview  2010-2023   92   161  15  7787  251  53.33  15284  50.94    26
#
#     50s  0s   4s  6s
#  0   33  10  863  18  ,
#          Unnamed: 0       Span  Mat  Inns  NO  Runs    HS     Avg    BF     SR  \
#  0     vs Australia  2011-2019    9    18   1   699   166   41.11  1208  57.86
#  1    vs Bangladesh  2013-2019    6     8   2   683  200*  113.83  1020  66.96
#  2       vs England  2013-2023   16    29   2   995   132   36.85  2366  42.05
#  3         vs India  2010-2021   13    24   1   871   131   37.86  1997  43.61
#  4      vs Pakistan  2011-2023   14    25   2  1519   238   66.04  2867  52.98
#  5  vs South Africa  2012-2017   10    16   2   665   176   47.50  1370  48.54
#  6     vs Sri Lanka  2012-2019   10    18   3   992  242*   66.13  1758  56.42
#  7   vs West Indies  2012-2020   10    17   1   970   251   60.62  2025  47.90
# ...

# %%
type(dfh)
# Out:
# list

# %%
len(dfh)
# Out:
# 23

# %%
dfh[0]
# Out:
#   Unnamed: 0       Span  Mat  Inns  NO  Runs   HS    Avg     BF     SR  100s  \
# 0   overview  2010-2023   92   161  15  7787  251  53.33  15284  50.94    26
#
#    50s  0s   4s  6s
# 0   33  10  863  18

# %%
dfh[1]
# Out:
#         Unnamed: 0       Span  Mat  Inns  NO  Runs    HS     Avg    BF     SR  \
# 0     vs Australia  2011-2019    9    18   1   699   166   41.11  1208  57.86
# 1    vs Bangladesh  2013-2019    6     8   2   683  200*  113.83  1020  66.96
# 2       vs England  2013-2023   16    29   2   995   132   36.85  2366  42.05
# 3         vs India  2010-2021   13    24   1   871   131   37.86  1997  43.61
# 4      vs Pakistan  2011-2023   14    25   2  1519   238   66.04  2867  52.98
# 5  vs South Africa  2012-2017   10    16   2   665   176   47.50  1370  48.54
# 6     vs Sri Lanka  2012-2019   10    18   3   992  242*   66.13  1758  56.42
# 7   vs West Indies  2012-2020   10    17   1   970   251   60.62  2025  47.90
# 8      vs Zimbabwe  2011-2016    4     6   1   393   113   78.60   673  58.39
#
#    100s  50s  0s   4s  6s
# 0     2    2   2   93   0
# 1     3    4   0   73   2
# 2     4    4   3  118   1
# 3     2    5   1   93   2
# 4     5    4   0  158   4
# ...

# %%
dfh[22]
# Out:
#      Unnamed: 0       Span  Mat  Inns  NO  Runs    HS    Avg     BF     SR  \
# 0  3rd position  2011-2023   82   141  14  7169   251  56.44  13714  52.27
# 1  4th position  2011-2021    3     3   1   126  102*  63.00    342  36.84
# 2  5th position  2010-2012    6     8   0   202    77  25.25    494  40.89
# 3  6th position  2010-2012    5     7   0   278   131  39.71    697  39.88
# 4  7th position  2010-2010    2     2   0    12     8   6.00     37  32.43
#
#    100s  50s  0s   4s  6s
# 0    24   30   6  803  18
# 1     1    0   1   12   0
# 2     0    1   2   22   0
# 3     1    2   1   26   0
# 4     0    0   0    0   0

# %%
type(dfh[2])
# Out:
# pandas.core.frame.DataFrame

# %%
import os
ori=os.getcwd()
os.mkdir(ori+'\\kanestats')
os.chdir(ori+'\\kanestats')
count=0
for i in dfh:
    count+=1
    i.to_csv('kane_'+str(count)+'_.csv',index=False)
os.chdir(ori)

# %%
pwd()
# Out:
# 'C:\\Users\\91868\\Data Science\\pandas'

# %%
import pandas as pd

# %%
ff=pd.read_csv('uk-500.csv')

# %%
ff.to_pickle('newpickle')

# %%
ff
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
ff1=pd.read_pickle('newpickle')

# %%
ff1
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
newh5=pd.HDFStore('newh5.h5')

# %%
type(newh5)
# Out:
# pandas.io.pytables.HDFStore

# %%
newh5['ff']=ff

# %%
f1=newh5['ff']

# %%
f1
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
newh5.close()

# %%
newh5
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: newh5.h5

# %%
type(f1)
# Out:
# pandas.core.frame.DataFrame

# %%
newh5.open()

# %%
newh5.items()
# Out:
# <generator object HDFStore.items at 0x000002A376DDA890>

# %%
newh5.keys()
# Out:
# ['/ff']

# %%
newh5.root
# Out:
# / (RootGroup) ''
#   children := ['ff' (Group)]

# %%
newh5.put('ff2',ff1,format='table',index=False)

# %%
newh5['ff2']
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
newh5.put('ff3',ff1,format='table',index=True)

# %%
newh5['ff3']
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
newh5.select('ff2',where=['index>=5 and index<=15'])
# Out:
#      first_name  last_name                   company_name  \
# 5          Eric      Rampy        Thompson, Michael C Esq
# 6          Marg   Grasmick  Wrangle Hill Auto Auct & Slvg
# 7       Laquita      Hisaw          In Communications Inc
# 8          Lura   Manzella                Bizerba Usa Inc
# 9        Yuette     Klapec                      Max Video
# 10     Fernanda     Writer           K & R Associates Inc
# 11  Charlesetta        Erm               Cain, John M Esq
# 12     Corrinne      Jaret              Sound Vision Corp
# 13       Niesha      Bruch         Rowley/hansell Petetin
# 14       Rueben  Gastellum  Industrial Engineering Assocs
# 15      Michell  Throssell            Weiss Spirt & Guyer
#
#                  address                            city  \
# 5           9472 Lind St                      Desborough
# 6       7457 Cowl St #70                    Bargate Ward
# 7   20 Gloucester Pl #96                    Chirton Ward
# ...

# %%
newh5
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: newh5.h5

# %%
df=pd.read_csv('nw.csv')

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df.dtypes
# Out:
# Symbol             object
# Name               object
# Sector             object
# Price             float64
# Price/Earnings    float64
# Dividend Yield    float64
# Earnings/Share    float64
# 52 Week Low       float64
# 52 Week High      float64
# Market Cap          int64
# EBITDA            float64
# Price/Sales       float64
# Price/Book        float64
# SEC Filings        object
# dtype: object

# %%
df.describe(percentiles=None)
# Out:
#              Price  Price/Earnings  Dividend Yield  Earnings/Share  \
# count   505.000000      503.000000      505.000000      505.000000
# mean    103.830634       24.808390        1.895953        3.753743
# std     134.427636       41.241081        1.537214        5.689036
# min       2.820000     -251.530000        0.000000      -28.010000
# 25%      46.250000       15.350000        0.794834        1.490000
# 50%      73.920000       19.450000        1.769255        2.890000
# 75%     116.540000       25.750000        2.781114        5.140000
# max    1806.060000      520.150000       12.661196       44.090000
#
#        52 Week Low  52 Week High    Market Cap        EBITDA  Price/Sales  \
# count   505.000000    505.000000  5.050000e+02  5.050000e+02   505.000000
# mean    122.623832     83.536616  4.923944e+10  3.590328e+09     3.941705
# std     155.362140    105.725473  9.005017e+10  6.840544e+09     3.460110
# ...

# %%
df.describe(include=[object,'category'])
# Out:
#        Symbol        Name                  Sector  \
# count     505         505                     505
# unique    505         505                      11
# top       MMM  3M Company  Consumer Discretionary
# freq        1           1                      84
#
#                                               SEC Filings
# count                                                 505
# unique                                                505
# top     http://www.sec.gov/cgi-bin/browse-edgar?action...
# freq                                                    1

# %%
df.columns
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price/Earnings', 'Dividend Yield',
#        'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA',
#        'Price/Sales', 'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
df.dtypes=='object'
# Out:
# Symbol             True
# Name               True
# Sector             True
# Price             False
# Price/Earnings    False
# Dividend Yield    False
# Earnings/Share    False
# 52 Week Low       False
# 52 Week High      False
# Market Cap        False
# EBITDA            False
# Price/Sales       False
# Price/Book        False
# SEC Filings        True
# dtype: bool

# %%
df.dtypes[df.dtypes=='object']
# Out:
# Symbol         object
# Name           object
# Sector         object
# SEC Filings    object
# dtype: object

# %%
l=(df.dtypes)

# %%
l
# Out:
# Symbol             object
# Name               object
# Sector             object
# Price             float64
# Price/Earnings    float64
# Dividend Yield    float64
# Earnings/Share    float64
# 52 Week Low       float64
# 52 Week High      float64
# Market Cap          int64
# EBITDA            float64
# Price/Sales       float64
# Price/Book        float64
# SEC Filings        object
# dtype: object

# %%
len(l)
# Out:
# 14

# %%
l[7]
# Out:
# dtype('float64')

# %%
l['Symbol']
# Out:
# dtype('O')

# %%
l.items
# Out:
# <bound method Series.items of Symbol             object
# Name               object
# Sector             object
# Price             float64
# Price/Earnings    float64
# Dividend Yield    float64
# Earnings/Share    float64
# 52 Week Low       float64
# 52 Week High      float64
# Market Cap          int64
# EBITDA            float64
# Price/Sales       float64
# Price/Book        float64
# SEC Filings        object
# dtype: object>

# %%
type(l)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
l.index
# Out:
# Index(['Symbol', 'Name', 'Sector', 'Price', 'Price/Earnings', 'Dividend Yield',
#        'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA',
#        'Price/Sales', 'Price/Book', 'SEC Filings'],
#       dtype='object')

# %%
for i in l.index:
    if l[i]=='object':
        print(i)
# Out:
# Symbol
# Name
# Sector
# SEC Filings

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Symbol', 'Name', 'Sector', 'SEC Filings'], dtype='object')

# %%
df1=df[df.dtypes[df.dtypes=='object'].index]

# %%
df1.describe()
# Out:
#        Symbol        Name                  Sector  \
# count     505         505                     505
# unique    505         505                      11
# top       MMM  3M Company  Consumer Discretionary
# freq        1           1                      84
#
#                                               SEC Filings
# count                                                 505
# unique                                                505
# top     http://www.sec.gov/cgi-bin/browse-edgar?action...
# freq                                                    1

# %%
type(df[['Name','Price']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df[["Name"]]
# Out:
#                        Name
# 0                3M Company
# 1           A.O. Smith Corp
# 2       Abbott Laboratories
# 3               AbbVie Inc.
# 4             Accenture plc
# ..                      ...
# 500              Xylem Inc.
# 501         Yum! Brands Inc
# 502  Zimmer Biomet Holdings
# 503           Zions Bancorp
# 504                  Zoetis
#
# [505 rows x 1 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=505, step=1)

# %%
df['Name'][5:25]
# Out:
# 5                     Activision Blizzard
# 6                       Acuity Brands Inc
# 7                       Adobe Systems Inc
# 8                      Advance Auto Parts
# 9              Advanced Micro Devices Inc
# 10                               AES Corp
# 11                              Aetna Inc
# 12          Affiliated Managers Group Inc
# 13                              AFLAC Inc
# 14               Agilent Technologies Inc
# 15           Air Products & Chemicals Inc
# 16                Akamai Technologies Inc
# 17                   Alaska Air Group Inc
# 18                         Albemarle Corp
# 19    Alexandria Real Estate Equities Inc
# 20                Alexion Pharmaceuticals
# 21                       Align Technology
# 22                               Allegion
# 23                          Allergan, Plc
# 24                  Alliance Data Systems
# Name: Name, dtype: object

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
for i in df.columns:
    print(df[i],df[[i]])
# Out:
# 0       MMM
# 1       AOS
# 2       ABT
# 3      ABBV
# 4       ACN
#        ...
# 500     XYL
# 501     YUM
# 502     ZBH
# 503    ZION
# 504     ZTS
# Name: Symbol, Length: 505, dtype: object     Symbol
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4      ACN
# ..     ...
# 500    XYL
# 501    YUM
# 502    ZBH
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]
# 0                  3M Company
# 1             A.O. Smith Corp
# 2         Abbott Laboratories
# 3                 AbbVie Inc.
# 4               Accenture plc
#                 ...
# 500                Xylem Inc.
# 501           Yum! Brands Inc
# 502    Zimmer Biomet Holdings
# 503             Zions Bancorp
# 504                    Zoetis
# Name: Name, Length: 505, dtype: object                        Name
# 0                3M Company
# 1           A.O. Smith Corp
# 2       Abbott Laboratories
# 3               AbbVie Inc.
# 4             Accenture plc
# ..                      ...
# 500              Xylem Inc.
# ...

# %%
df['newcol']='vamsi'

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df['new2']=list(range(505))

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df['new3']=list(range(300))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34484/2131509468.py in <module>
# ----> 1 df['new3']=list(range(300))
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# -> 4504             com.require_length_match(value, self.index)
# ...

# %%
df['new3']=df['Price/Book']

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df.describe(include='all')
# Out:
#        Symbol        Name                  Sector        Price  \
# count     505         505                     505   505.000000
# unique    505         505                      11          NaN
# top       MMM  3M Company  Consumer Discretionary          NaN
# freq        1           1                      84          NaN
# mean      NaN         NaN                     NaN   103.830634
# std       NaN         NaN                     NaN   134.427636
# min       NaN         NaN                     NaN     2.820000
# 25%       NaN         NaN                     NaN    46.250000
# 50%       NaN         NaN                     NaN    73.920000
# 75%       NaN         NaN                     NaN   116.540000
# max       NaN         NaN                     NaN  1806.060000
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# count       503.000000      505.000000      505.000000   505.000000
# unique             NaN             NaN             NaN          NaN
# ...

# %%
df['Sector']
# Out:
# 0                 Industrials
# 1                 Industrials
# 2                 Health Care
# 3                 Health Care
# 4      Information Technology
#                 ...
# 500               Industrials
# 501    Consumer Discretionary
# 502               Health Care
# 503                Financials
# 504               Health Care
# Name: Sector, Length: 505, dtype: object

# %%
pd.Categorical(df['Sector'])
# Out:
# ['Industrials', 'Industrials', 'Health Care', 'Health Care', 'Information Technology', ..., 'Industrials', 'Consumer Discretionary', 'Health Care', 'Financials', 'Health Care']
# Length: 505
# Categories (11, object): ['Consumer Discretionary', 'Consumer Staples', 'Energy', 'Financials', ..., 'Materials', 'Real Estate', 'Telecommunication Services', 'Utilities']

# %%
df['new4']=pd.Categorical(df['Sector'])

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
df.dtypes
# Out:
# Symbol              object
# Name                object
# Sector              object
# Price              float64
# Price/Earnings     float64
# Dividend Yield     float64
# Earnings/Share     float64
# 52 Week Low        float64
# 52 Week High       float64
# Market Cap           int64
# EBITDA             float64
# Price/Sales        float64
# Price/Book         float64
# SEC Filings         object
# newcol              object
# new2                 int64
# new3               float64
# new4              category
# dtype: object

# %%
df.describe(include=['category'])
# Out:
#                           new4
# count                      505
# unique                      11
# top     Consumer Discretionary
# freq                        84

# %%
type(df['new4'])
# Out:
# pandas.core.series.Series

# %%
df['new4']
# Out:
# 0                 Industrials
# 1                 Industrials
# 2                 Health Care
# 3                 Health Care
# 4      Information Technology
#                 ...
# 500               Industrials
# 501    Consumer Discretionary
# 502               Health Care
# 503                Financials
# 504               Health Care
# Name: new4, Length: 505, dtype: category
# Categories (11, object): ['Consumer Discretionary', 'Consumer Staples', 'Energy', 'Financials', ..., 'Materials', 'Real Estate', 'Telecommunication Services', 'Utilities']

# %%
#df.describe(include='all')
df['Sector'].uniqueque()
# Out:
# array(['Industrials', 'Health Care', 'Information Technology',
#        'Consumer Discretionary', 'Utilities', 'Financials', 'Materials',
#        'Real Estate', 'Consumer Staples', 'Energy',
#        'Telecommunication Services'], dtype=object)

# %%
df.describe(include='all')
# Out:
#        Symbol        Name                  Sector        Price  \
# count     505         505                     505   505.000000
# unique    505         505                      11          NaN
# top       MMM  3M Company  Consumer Discretionary          NaN
# freq        1           1                      84          NaN
# mean      NaN         NaN                     NaN   103.830634
# std       NaN         NaN                     NaN   134.427636
# min       NaN         NaN                     NaN     2.820000
# 25%       NaN         NaN                     NaN    46.250000
# 50%       NaN         NaN                     NaN    73.920000
# 75%       NaN         NaN                     NaN   116.540000
# max       NaN         NaN                     NaN  1806.060000
#
#         Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# count       503.000000      505.000000      505.000000   505.000000
# unique             NaN             NaN             NaN          NaN
# ...

# %%
print(df['Price/Book'][df['Price/Book'].isnull()])
print(df['Price/Book'][df['Price/Book'].isnull()==False])
print(df['Price/Book'][df['Price/Book'].isnull()].index)
# Out:
# 55    NaN
# 199   NaN
# 225   NaN
# 292   NaN
# 346   NaN
# 358   NaN
# 450   NaN
# 460   NaN
# Name: Price/Book, dtype: float64
# 0       11.34
# 1        6.35
# 2        3.19
# 3       26.14
# 4       10.62
#         ...
# 500      5.31
# 501    212.08
# 502      2.39
# 503      1.42
# 504     18.09
# Name: Price/Book, Length: 497, dtype: float64
# Int64Index([55, 199, 225, 292, 346, 358, 450, 460], dtype='int64')

# %%
s=df['Price/Book'][df['Price/Book'].isnull()].index
df.iloc[s]
# Out:
#     Symbol                  Name                  Sector   Price  \
# 55    ARNC           Arconic Inc             Industrials   24.45
# 199     FL       Foot Locker Inc  Consumer Discretionary   45.88
# 225    HCA          HCA Holdings             Health Care   95.97
# 292    MRO    Marathon Oil Corp.                  Energy   15.68
# 346    OXY  Occidental Petroleum                  Energy   68.47
# 358    PEP          PepsiCo Inc.        Consumer Staples  110.15
# 450    TDG       TransDigm Group             Industrials  283.00
# 460    UNP         Union Pacific             Industrials  124.86
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 55            20.21        0.956175           -0.21        31.17
# 199            9.50        2.582795            4.91        77.86
# 225           14.07        1.422764            5.94       106.84
# 292          -32.00        1.224740           -2.65        19.52
# ...

# %%
df.iloc[[2,5,3,233,232,466,9,10,0]]
# Out:
#     Symbol                             Name                  Sector   Price  \
# 2      ABT              Abbott Laboratories             Health Care   56.27
# 5     ATVI              Activision Blizzard  Information Technology   65.83
# 3     ABBV                      AbbVie Inc.             Health Care  108.48
# 233     HD                       Home Depot  Consumer Discretionary  181.22
# 232   HOLX                          Hologic             Health Care   38.80
# 466    UHS  Universal Health Services, Inc.             Health Care  114.87
# 9      AMD       Advanced Micro Devices Inc  Information Technology   11.22
# 10     AES                         AES Corp               Utilities   10.06
# 0      MMM                       3M Company             Industrials  222.89
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 2             22.51        1.908982            0.26       64.600
# 5             31.80        0.431903            1.28       74.945
# ...

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
max(df['Price'])
# Out:
# 1806.06

# %%
df['Name'][df['Price']==max(df['Price'])]
# Out:
# 372    Priceline.com Inc
# Name: Name, dtype: object

# %%
df['new5']=df['Name']+'/'+df['Sector']

# %%
df
# Out:
#     Symbol                    Name                  Sector   Price  \
# 0      MMM              3M Company             Industrials  222.89
# 1      AOS         A.O. Smith Corp             Industrials   60.24
# 2      ABT     Abbott Laboratories             Health Care   56.27
# 3     ABBV             AbbVie Inc.             Health Care  108.48
# 4      ACN           Accenture plc  Information Technology  150.51
# ..     ...                     ...                     ...     ...
# 500    XYL              Xylem Inc.             Industrials   70.24
# 501    YUM         Yum! Brands Inc  Consumer Discretionary   76.30
# 502    ZBH  Zimmer Biomet Holdings             Health Care  115.53
# 503   ZION           Zions Bancorp              Financials   50.71
# 504    ZTS                  Zoetis             Health Care   71.51
#
#      Price/Earnings  Dividend Yield  Earnings/Share  52 Week Low  \
# 0             24.31        2.332862            7.92       259.77
# ...

# %%
dfn=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
dfn
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...
